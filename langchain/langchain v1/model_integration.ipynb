# %% [markdown]
# ### Models Integration with OpenAI, Google Gemini and Groq

# %%
import os
from typing import cast
from dotenv import load_dotenv
from pydantic import SecretStr

load_dotenv()

api_key = cast(SecretStr, os.getenv("OPENROUTER_API_KEY"))
base_url = os.getenv("BASE_URL")

os.environ["OPENROUTER_API_KEY"]=os.getenv("OPENROUTER_API_KEY", "")
os.environ["LANGSMITH_API_KEY"]=os.getenv("LANGSMITH_API_KEY", "")
os.environ["LANGSMITH_TRACING"]=os.getenv("LANGSMITH_TRACING", "")
os.environ["LANGSMITH_PROJECT"]=os.getenv("LANGSMITH_PROJECT", "")

# %% [markdown]
# #### OpenAI Model Integration

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model = "gpt-oss-20b:free",
    base_url = base_url,
    api_key = api_key
)
print(model) # Check if the model is initialized correctly

# Invoke the model
res = model.invoke("Hello how are you?")
print(res.content)
# Out:
# d:\Agentic AI 101\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# profile={} client=<openai.resources.chat.completions.completions.Completions object at 0x000001603BD9A660> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001603BD9B0E0> root_client=<openai.OpenAI object at 0x000001603B844050> root_async_client=<openai.AsyncOpenAI object at 0x000001603BD9AE40> model_name='gpt-oss-20b:free' model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://openrouter.ai/api/v1'
# Hello! I’m doing great—thanks for asking. How can I help you today?

# %% [markdown]
# ChatOpenAI is a wrapper around OpenAI's chat models. It can also be used here instead of init_chat_model.

# %% [markdown]
# #### Google Model Integration

# %%
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model = "google/gemma-3-27b-it:free",
    api_key = api_key,
    base_url = base_url
)
print(model)

# Invoke the model
res = model.invoke("Hello how are you?")
print(res.content)
# Out:
# profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<openrouter.sdk.OpenRouter object at 0x000001A3B5B596A0> openrouter_api_key=SecretStr('**********') openrouter_api_base='https://openrouter.ai/api/v1' app_url='https://docs.langchain.com/oss' app_title='langchain' model_name='google/gemma-3-27b-it:free' model_kwargs={}
# Hi there! As an AI, I don't *feel* in the same way people do, but I'm functioning perfectly and ready to help! So you could say I'm doing well. 😄
#
# How are *you* doing today? Is there anything I can do for you?

# %% [markdown]
# ### Groq Model Integration

# %%
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model = "qwen/qwen3-next-80b-a3b-instruct:free",
    api_key = api_key,
    base_url = base_url
)
print(model)

# Invoke the model
res = model.invoke("Hello how are you?")
print(res.content)
# Out:
# profile={'max_input_tokens': 262144, 'max_output_tokens': 262144, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True} client=<openrouter.sdk.OpenRouter object at 0x000001A3C7E8D450> openrouter_api_key=SecretStr('**********') openrouter_api_base='https://openrouter.ai/api/v1' app_url='https://docs.langchain.com/oss' app_title='langchain' model_name='qwen/qwen3-next-80b-a3b-instruct:free' model_kwargs={}
